# %%
BUILDING = 2
FLOOR = 0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import pandas as pd 
import torchvision
from torchvision import datasets, transforms
from torch import nn,optim
import torch.nn.functional as F
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = [3.14,2.8,2.89,2.88]
y = [4.31,4.51,3.67,5.74]
z = [5.08,4.99,4.36,6.04]
# plot lines
plt.plot(x,  '-gD',label = "Traditional DNN")
plt.plot(y, '--bo',label = "Tuning")
plt.plot(z, '--d',label = "Feature selection")
plt.title("Building 0",fontweight='bold')
plt.xlabel("Floor")
plt.ylabel("Distance error")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = [4.3,3.26,3.38,2.78]
y = [5.62,5.19,5.43,3.96]
z = [6.52,5.62,5.68,4.43]
# plot lines
plt.plot(x,  '-gD',label = "Traditional DNN")
plt.plot(y, '--bo',label = "Tuning")
plt.plot(z, '--d',label = "Feature selection")
plt.title("Building 2",fontweight="bold")
plt.xlabel("Floor")
plt.ylabel("Distance error")
plt.legend()
plt.show()

# %%
def convert_data_to_tensor(np_data,device):
    return torch.tensor(np_data,dtype=torch.float32).to(device)

def create_data_loader(np_input, np_label, batch_size, shuffle=False):
    device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

    input = Variable(convert_data_to_tensor(np_input,device))
    label = Variable(convert_data_to_tensor(np_label,device))

    if torch.cuda.is_available():
        input = input.cuda()
        label = label.cuda()

    data_loader = DataLoader(dataset=TensorDataset(input,label),
                             batch_size=batch_size,
                             shuffle=shuffle)
    return data_loader


def scale_data(rss_df):
    if not('pandas' in str(type(rss_df))):
        print("ERROR: Please Input Data in pandas.DataFrame")
        return -1

    new_rss = rss_df.copy()
    new_rss[new_rss == 100] = -110
    new_rss[new_rss == -100] = -110

    new_rss /= 110
    new_rss += 1
    return new_rss.values

def scale_xy(lon_lat, mean, std):
    return (lon_lat - mean) / std

def rescale_xy(scale_lon_lat, mean, std):
    scale_lon_lat = np.array(scale_lon_lat)
    lon = np.transpose(np.array([scale_lon_lat[:, 0]]))
    # lon = output[0]
    lon_rescaled = lon * std[0] + mean[0]

    lat = np.transpose(np.array([scale_lon_lat[:, 1]]))
    # lat = output[1]
    lat_rescaled = lat * std[1] + mean[1]
    return np.array([lon_rescaled, lat_rescaled]).transpose().reshape(-1,2)


def save_result (df_pred, df_true, data_name, case_name, save_path):
    # % SAVE RESULT
    df_result = df_pred.copy()

    df_result.join(df_true)
    file_path = join(save_path, "pred_{}_{}.csv".format(data_name,case_name))
    df_result.to_csv(file_path,header=True)


    # % Evaluate the Result
    eval_euclidean_distance(
        df_pred = df_pred,
        df_truth = df_true,
        dataset_name = data_name,
        case_name = case_name,
        save_path = save_path,
        run_time=-1,
        file_name="Eval_Results.csv",
        saveFlag=True
    )

    # Plot - Result
    Plot2Dlocation(df_true.values, [[case_name, df_pred.values]], save_path, data_name, case_name,
                   connectDots=True, saveFlag=True)

    print("-- [complete] save pred_{}_{}.csv".format(data_name,case_name))
#end save_result

# %%
data = pd.read_csv('path-to-csv')
data = data[data["BuildingID"]==BUILDING]
data = data[data["FloorID"]==FLOOR]
label = data[["x","y"]]

#data = data.drop(columns=['type','timestamp','longitude','latitude','floor_id'])
data = data.drop(columns=["lon","lat","FloorID","BuildingID","locID","RELATIVEPOSITION","USERID","PHONEID","TIMESTAMP","pos_loc","SectionID","x","y"])
print(data)

X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)




#Normalize training input data
X_train = scale_data(X_train)

#Normalize training label: 
mean = np.mean(y_train.values, axis=0)
std = np.std(y_train.values, axis=0)
label = scale_xy(y_train.values, mean, std)



#convert df to tensor object
data = torch.tensor(X_train)

label_t = torch.tensor(label)

#flatten 
data_t = torch.flatten(data,1)

label_t = torch.flatten(label_t,1)
print("data shape: " + str(data_t.shape))
print("label shape: " + str(label_t.shape))


train_data = [] 
for i in range(len(data_t)):
    train_data.append([data_t[i],label_t[i]])
# Out:
#        WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 3273     -100    -100    -100     -64    -100    -100    -100    -100    -100
# 3274     -100    -100    -100     -49    -100    -100    -100    -100    -100
# 3275     -100    -100    -100    -100    -100    -100    -100    -100    -100
# 3276     -100    -100    -100     -75    -100    -100    -100    -100    -100
# 3277     -100    -100    -100     -62    -100    -100    -100    -100    -100
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 13471    -100    -100    -100    -100    -100    -100    -100    -100    -100
# 13472    -100    -100    -100    -100    -100    -100    -100    -100    -100
# 13473    -100    -100    -100    -100    -100    -100    -100    -100    -100
# 13474    -100    -100    -100     -93    -100    -100    -100    -100    -100
# 13475    -100    -100    -100    -100    -100    -100    -100    -100    -100
#
#        WAP010  ...  WAP511  WAP512  WAP513  WAP514  WAP515  WAP516  WAP517  \
# 3273     -100  ...    -100    -100    -100    -100    -100    -100    -100
# 3274     -100  ...    -100    -100    -100    -100    -100    -100    -100
# 3275     -100  ...    -100    -100    -100    -100    -100    -100    -100
# 3276     -100  ...    -100    -100    -100    -100    -100    -100    -100
# 3277     -100  ...    -100    -100    -100    -100    -100    -100    -100
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 13471    -100  ...    -100    -100    -100    -100    -100    -100    -100
# 13472    -100  ...    -100    -100    -100    -100    -100    -100    -100
# 13473    -100  ...    -100    -100    -100    -100    -100    -100    -100
# 13474    -100  ...    -100    -100    -100    -100    -100    -100    -100
# 13475    -100  ...    -100    -100    -100    -100    -100    -100    -100
#
#        WAP518  WAP519  WAP520
# 3273     -100    -100    -100
# 3274     -100    -100    -100
# 3275     -100    -100    -100
# 3276     -100    -100    -100
# 3277     -100    -100    -100
# ...       ...     ...     ...
# 13471    -100    -100    -100
# 13472    -100    -100    -100
# 13473    -100    -100    -100
# 13474    -100    -100    -100
# 13475    -100    -100    -100
#
# [1356 rows x 520 columns]
# data shape: torch.Size([1084, 520])
# label shape: torch.Size([1084, 2])

# %%
#Normalize test input data 
X_test = scale_data(X_test) 

#Normalize training label
mean_val = np.mean(y_test.values, axis=0)
std_val = np.std(y_test.values, axis=0)
label_val = scale_xy(y_test.values, mean_val, std_val)




#convert df to tensor object
data_val_t1 = torch.tensor(X_test)

label_val_t = torch.tensor(label_val)

#flatten 
data_val_t = torch.flatten(data_val_t1,1)

label_val_t = torch.flatten(label_val_t,1)
print("data shape: " + str(data_val_t.shape))
print("label shape: " + str(label_val_t.shape))

val_data = [] 
for i in range(len(data_val_t)):
    val_data.append([data_val_t[i],label_val_t[i]])
# Out:
# data shape: torch.Size([272, 520])
# label shape: torch.Size([272, 2])

# %%
GRAPH_COLOUR = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
MARKER = ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']

plt.figure(figsize=(10, 7))
x,y = label.T
plt.scatter(x,y)
plt.show()

# %%
#put both train and validation sets into loader 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=32)
testloader = torch.utils.data.DataLoader(val_data, batch_size=32)

print("Finish dataset part")
# Out:
# Finish dataset part

# %%
class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(data_val_t.shape[1],300)
        self.fc2 = nn.Linear(300,300)
        self.fc3 = nn.Linear(300,300)
        self.fc4 = nn.Linear(300,2)

        
        self.dropout = nn.Dropout(p=0.5)
        
    def forward(self,x):
        x = x.view(x.shape[0],-1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        x = self.fc4(x)
        
        return x

# %%
def weight_reset(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        m.reset_parameters()

# %%
import time 
LR = 0.0001


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Computation device: {device}\n")
model = Classifier()
model.apply(weight_reset)
model.to(device)
#optimizer = optim.Adam(model.parameters(), lr= LR, eps = 1e-9) 
optimizer = optim.Adam(model.parameters(), lr= LR) 

#optimizer = optim.SGD(model.parameters(), lr = 0.001, weight_decay=0.03, momentum=0.003)
#optimizer = optim.SGD(model.parameters(), lr = LR)
criterion = nn.MSELoss() #MSE
#criterion = torch.nn.L1Loss()

epochs = 500
train_losses, test_losses = [],[]
times = []
for e in range(epochs):
    start_epoch = time.time()
    tot_train_loss = 0 
    for data, labels in trainloader:
        data, labels = data.to(device), labels.to(device)
        data = data.view(data.shape[0],-1)
        data = data.float()
        optimizer.zero_grad()
        output = model(data)
        #print(output)
        #output = ((output - torch.mean(output))/torch.max(output)-torch.min(output))
        loss = torch.sqrt(criterion(output,labels.float())) #RMSE 
        #loss = criterion(output,labels.float())
        tot_train_loss+=loss.item()
        
        loss.backward()
        optimizer.step()
        


    else:
        #if e>=100 and e%5==0 :
            #torch.save(model.state_dict(), './outputs/dec_control/dec-epoch-{}.pth'.format(e))
        tot_test_loss = 0 
        with torch.no_grad():
            for data, labels in testloader:
                data, labels = data.to(device), labels.to(device)
                data = data.view(data.shape[0],-1)
                data=data.float()
                test_output = model(data)
                loss = torch.sqrt(criterion(test_output,labels.float()))
                #loss = criterion(test_output,labels.float())

                tot_test_loss+=loss.item()
                
        train_loss = tot_train_loss/len(trainloader.dataset)
        test_loss = tot_test_loss/len(trainloader.dataset)
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        end_epoch = time.time()
        elapsed = end_epoch - start_epoch 
        times.append(elapsed)
        print("Epoch:{}/{}..".format(e+1,epochs),
             "Training Loss:{:.3f}..".format(train_loss),
             "Test Loss:{:.3f}..".format(test_loss))
# Out:
# Computation device: cpu
#
# Epoch:1/500.. Training Loss:0.031.. Test Loss:0.008..
# Epoch:2/500.. Training Loss:0.031.. Test Loss:0.008..
# Epoch:3/500.. Training Loss:0.031.. Test Loss:0.008..
# Epoch:4/500.. Training Loss:0.029.. Test Loss:0.007..
# Epoch:5/500.. Training Loss:0.025.. Test Loss:0.006..
# Epoch:6/500.. Training Loss:0.019.. Test Loss:0.004..
# Epoch:7/500.. Training Loss:0.015.. Test Loss:0.004..
# Epoch:8/500.. Training Loss:0.014.. Test Loss:0.004..
# Epoch:9/500.. Training Loss:0.013.. Test Loss:0.004..
# Epoch:10/500.. Training Loss:0.013.. Test Loss:0.003..
# Epoch:11/500.. Training Loss:0.012.. Test Loss:0.003..
# Epoch:12/500.. Training Loss:0.012.. Test Loss:0.003..
# Epoch:13/500.. Training Loss:0.012.. Test Loss:0.003..
# Epoch:14/500.. Training Loss:0.012.. Test Loss:0.003..
# Epoch:15/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:16/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:17/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:18/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:19/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:20/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:21/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:22/500.. Training Loss:0.011.. Test Loss:0.003..
# Epoch:23/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:24/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:25/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:26/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:27/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:28/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:29/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:30/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:31/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:32/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:33/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:34/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:35/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:36/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:37/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:38/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:39/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:40/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:41/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:42/500.. Training Loss:0.010.. Test Loss:0.003..
# Epoch:43/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:44/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:45/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:46/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:47/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:48/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:49/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:50/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:51/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:52/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:53/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:54/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:55/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:56/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:57/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:58/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:59/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:60/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:61/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:62/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:63/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:64/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:65/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:66/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:67/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:68/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:69/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:70/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:71/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:72/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:73/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:74/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:75/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:76/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:77/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:78/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:79/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:80/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:81/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:82/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:83/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:84/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:85/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:86/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:87/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:88/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:89/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:90/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:91/500.. Training Loss:0.009.. Test Loss:0.002..
# Epoch:92/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:93/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:94/500.. Training Loss:0.009.. Test Loss:0.003..
# Epoch:95/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:96/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:97/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:98/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:99/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:100/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:101/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:102/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:103/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:104/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:105/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:106/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:107/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:108/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:109/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:110/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:111/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:112/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:113/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:114/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:115/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:116/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:117/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:118/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:119/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:120/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:121/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:122/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:123/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:124/500.. Training Loss:0.008.. Test Loss:0.003..
# Epoch:125/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch:126/500.. Training Loss:0.008.. Test Loss:0.002..
# Epoch
 0.2709221839904785, 0.25078582763671875, 0.2695794105529785, 0.26257777214050293, 0.2735893726348877, 0.25548672676086426, 0.2646815776824951, 0.27179932594299316, 0.26500773429870605, 0.2574348449707031, 0.26576876640319824, 0.27816057205200195, 0.26416945457458496, 0.268726110458374, 0.2621631622314453, 0.27342724800109863, 0.26186251640319824, 0.2625091075897217, 0.26691699028015137, 0.2863185405731201, 0.27144598960876465, 0.2719583511352539, 0.28321027755737305, 0.26732373237609863, 0.2708601951599121, 0.2603886127471924, 0.2736825942993164, 0.2636270523071289, 0.25856542587280273, 0.257885217666626, 0.2519717216491699, 0.25618696212768555, 0.26411008834838867, 0.26233792304992676, 0.2782912254333496, 0.2692079544067383, 0.26412272453308105, 0.26760125160217285, 0.27892446517944336, 0.27258992195129395, 0.25947022438049316, 0.25743842124938965, 0.27717113494873047, 0.27100133895874023, 0.26186633110046387, 0.26651620864868164, 0.2661705017089844, 0.26746177673339844, 0.2624547481536865, 0.2570476531982422, 0.26886534690856934, 0.25182533264160156, 0.2560744285583496, 0.2618896961212158, 0.26708102226257324, 0.2675919532775879, 0.26923489570617676, 0.26362013816833496, 0.26074743270874023, 0.2594900131225586, 0.2598378658294678, 0.27139902114868164, 0.2563936710357666, 0.26252269744873047, 0.261568546295166, 0.2646205425262451, 0.2696802616119385, 0.2561495304107666, 0.26269006729125977, 0.26927685737609863, 0.260509729385376, 0.25861120223999023, 0.26403212547302246, 0.2634251117706299, 0.2566945552825928, 0.2603161334991455, 0.26487278938293457, 0.26789236068725586, 0.259199857711792, ...

# %%
import matplotlib.pyplot as plt


# loss plots
plt.figure(figsize=(10, 7))
plt.plot(train_losses, color='orange', label='train loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
#plt.savefig(f"./outputs/{loss_plot_name}.png")
plt.show()

# loss plots
plt.figure(figsize=(10, 7))
plt.plot(test_losses, color='red', label='validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
#plt.savefig(f"./outputs/{loss_plot_name}.png")
plt.show()

# %%
#validation_loss, validation_pred = evaluate(data_val_t, label_val_t, model, criterion, mean, std)

data_val_new = pd.read_csv('path-to-csv')
data_val_new = data_val_new[data_val_new["BuildingID"]==BUILDING]
data_val_new = data_val_new[data_val_new["FloorID"]==FLOOR]
label_val_new = data_val_new[["x","y"]]


data_val_new = data_val_new.drop(columns=["lon","lat","FloorID","BuildingID","locID","RELATIVEPOSITION","USERID","PHONEID","TIMESTAMP","pos_loc","SectionID","x","y"])


def evaluate(test_input, test_label, model, loss_fn, xy_mean, xy_std):
    model.eval()
    pred = model(convert_data_to_tensor(scale_data(test_input), device))
    val_loss = loss_fn(
        convert_data_to_tensor(rescale_xy(pred.data.cpu().numpy(), xy_mean, xy_std), device),
        convert_data_to_tensor(test_label, device)).data
    return val_loss.item(), rescale_xy(pred.data.cpu().numpy(), xy_mean, xy_std)

validation_loss, validation_pred = evaluate(data_val_new,label_val_new.values, model, criterion, mean, std)

# %%
print("Validation loss: " + str('{0:.2f}'.format(validation_loss)))
# Out:
# Validation loss: 29.11

# %%
dist_list = [] 
for i in range(len(validation_pred)):
    dist = np.linalg.norm(validation_pred[i]-label_val_new.values[i])
    dist_list.append(dist)
    
print("Validation loss: " + str('{0:.2f}'.format(validation_loss)))
print("Average: " + str('{0:.2f}'.format(np.average(dist_list))) + " m")
print("Min: " + str('{0:.2f}'.format(min(dist_list))) + " m")
print("Max: " + str('{0:.2f}'.format(max(dist_list))) + " m")
# Out:
# Validation loss: 29.11
# Average: 4.25 m
# Min: 0.13 m
# Max: 63.05 m

# %%
def Plot2Dlocation(np_xy_truth, list_xy_preds,result_path, dataset_name, plot_name, connectDots=True,saveFlag=False):
    """
    Plot the 2D map with the ground truth and prediction results (list_xy_preds could hold 1 set of results or more)
    :param main_info (HouseKeeping):
    :param np_xy_truth (Numpy):
    :param list_xy_preds (List<String,2d_np>): e.g. list_xy_preds=[["Euclidean",df_pred.values]]
    :param dataset_name (String):
    :param plot_name (String):
    :param connectDots (Bool):
    :param saveFlag (Bool):
    :return:
    """
    plt.clf()   #clear the plot
    fig, ax = plt.subplots(figsize=(16, 10))
    #Figure Info
    plt.title('{}\n({})'.format(plot_name,dataset_name))
    #plt.title(dataset_name,y=1)
    #plt.suptitle(plot_name, y=1.1, fontsize=18)
    #plt.title(dataset_name, fontsize=10)
    plt.xlabel('x')
    plt.ylabel('y')

    #plot groundtruth
    plt.plot(np_xy_truth[:,0], np_xy_truth[:,1], GRAPH_COLOUR[0]+MARKER[0],label="Ground Truth")

    #connect the points
    for caseNum in range(len(list_xy_preds)):
        #plot pred point (scatter)
        #plt.plot(list_xy_preds[caseNum][1][:, 0], list_xy_preds[caseNum][1][:, 1], GRAPH_COLOUR[caseNum+1] + MARKER[caseNum+1],label=list_xy_preds[caseNum][0])
        plt.scatter(list_xy_preds[caseNum][1][:, 0], list_xy_preds[caseNum][1][:, 1],c=GRAPH_COLOUR[caseNum+1],s=5,label=list_xy_preds[caseNum][0])

        if (connectDots):
            x = np.array([np_xy_truth[:, 0], list_xy_preds[caseNum][1][:, 0]])
            y = np.array([np_xy_truth[:, 1], list_xy_preds[caseNum][1][:, 1]])
            plt.plot(x, y, GRAPH_COLOUR[caseNum + 1], alpha=0.2)

    plt.legend()
    if saveFlag:
        saveName = join(result_path,dataset_name+"_"+plot_name+".png")
        plt.savefig(saveName)
    # plt.show()


    #endFunction Plot2Dlocation

# %%
temp_pred = [] 
for i in range(len(validation_pred)):
  temp_pred.append(validation_pred[i])
df_pred = pd.DataFrame(temp_pred)

# %%
Plot2Dlocation(label_val_new.values, [["Euclidean",df_pred.values]],"test",f"Building: {BUILDING} Floor: {FLOOR}","UJIndoor dataset")

# %%
#torch.save(model.state_dict(), f"/content/drive/MyDrive/FYP/UJI/UJI_MODEL_BUILDING{BUILDING}_FLOOR{FLOOR}")
